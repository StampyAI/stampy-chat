# %% [markdown]
# # Prompt Search Testing
#
# Idea: You start with a text (ex a page from a book), prompt(s), and hoped-for output(s).
# From the prompt and long text, generate multiple outputs, and order them by semantic similarity with the 'correct' outputs. Then, modify the prompt in various ways and repeat.
# Ways to modify the prompt:
# 	- Generate synonyms of the summary prompt and try the same thing. In other words, reformulate the prompt.
# 	- Generate infills for various [text, output] pairs to find prompts that are likely to generate the output.
# 	- Remove various words in the prmpt and infill multiple times.
#
# Basically, build a general algorithm that takes prompt(s) for a task, possibly input(s), and wanted outputs, and generate better prompts for the task.
#
# Function takes in the tuple ([prompt_11, prompt_12, ...], input_text_1, [desired_output_11, desired_output_12,...]), and outputs a list of prompts.
#
# Tasks this might be useful for:
# 	- Question answering (accuracy)
# 	- Summarization
# 	- Info extraction
# 	- Translation

# %%
# result = openai.Embedding.create(model=EMBEDDING_MODEL, input=text)
# answer = openai.Completion.create(prompt=prompt, **COMPLETIONS_API_PARAMS)["choices"][0]["text"].strip(" \n")

# %% [markdown]
# ## Imports

# %%
from typing import List, Dict, Tuple, Optional, Union, Any
import openai
import tokenize

import config

# %%
openai.api_key = config.OPENAI_API_KEY

# %% [markdown]
# ## Helpers

# %%
def reformulate(prompt: str):
    raise NotImplementedError

def infill_prompt(text: str, outputs: List[str]):
    raise NotImplementedError

def modify_prompt(prompt: str):
    raise NotImplementedError

# %% [markdown]
# ## Prompt Searcher

# %%
"""
Idea: You start with a text (ex a page from a book), prompt(s), and hoped-for output(s).
From the prompt and long text, generate multiple outputs, and order them by semantic similarity with the 'correct' outputs. Then, modify the prompt in various ways and repeat.
Ways to modify the prompt:
	- Generate synonyms of the summary prompt and try the same thing. In other words, reformulate the prompt.
	- Generate infills for various [text, output] pairs to find prompts that are likely to generate the output.
	- Modify the prompt in various ways (change single words for other synonymous words, etc).

Basically, build a general algorithm that takes prompt(s) for a task, possibly input(s), and wanted outputs, and generate better prompts for the task.

Function takes in the tuple ([prompt_11, prompt_12, ...], input_text_1, [desired_output_11, desired_output_12,...]), and outputs a list of prompts.

Tasks this might be useful for: 
	- Question answering (accuracy)
	- Summarization
	- Info extraction
	- Translation
 """

class PromptSearcher:
    def __init__(
            self,
            output_model: str = "code-davinci-002",
            reformulation_model: str = "gpt-3.5-turbo",
            embedding_model: str = "text-embedding-ada-002",
            endpoint: str = "https://api.openai.com/v1/completions",
            apikey: str = config.apikey
    ):
        self.output_model = output_model
        self.reformulation_model = reformulation_model
        self.embedding_model = embedding_model
        self.endpoint = endpoint
        self.apikey = apikey
    
    def reformulate(
        self,
        prompt: str,
        num_outputs: int = 5
    ) -> List[str]:
        """
        Reformulate the prompt using the reformulation model.

        Args:
            prompt (str): The prompt to reformulate.
            num_outputs (int, optional): The number of reformulated outputs. Defaults to 5.

        Returns:
            List[str]: The reformulated prompts.
        """
        raise NotImplementedError        
        
        # # Build the reformulation prompt
        # reformulation_prompt = f"Reformulate the following text. Try to modify it considerably while keeping all the same information.\n\nText: ```{prompt}```\n\nReformulated text:"
        
        # # Generate the reformulated prompts
        # reformulated_prompts = openai.Completion.create(
        #     prompt=reformulation_prompt,
        #     model=self.reformulation_model,
        #     max_tokens=100,
        #     temperature=0.5,
        #     top_p=1,
        #     frequency_penalty=0,
        #     presence_penalty=0,
        #     stop=["\n\n"]
        # )["choices"][:num_outputs]
        
        # # Return the reformulated prompts
        # return [choice["text"].strip(" \n") for choice in reformulated_prompts]
    
    def prompt_search(
        self,
        text: str,
        prompts: List[str],
        desired_outputs: List[str]
    ):
        raise NotImplementedError
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 20
#       1 """
#       2 Idea: You start with a text (ex a page from a book), prompt(s), and hoped-for output(s).
#       3 From the prompt and long text, generate multiple outputs, and order them by semantic similarity with the 'correct' outputs. Then, modify the prompt in various ways and repeat.
#    (...)
#      17 	- Translation
#      18  """
# ---> 20 class PromptSearcher:
#      21     def __init__(
#      22             self,
#      23             output_model: str = "code-davinci-002",
#    (...)
#      27             apikey: str = config.apikey
#      28     ):
#      29         self.output_model = output_model
#
# Cell In[5], line 27, in PromptSearcher()
#      20 class PromptSearcher:
#      21     def __init__(
#      22             self,
#      23             output_model: str = "code-davinci-002",
#      24             reformulation_model: str = "gpt-3.5-turbo",
#      25             embedding_model: str = "text-embedding-ada-002",
#      26             endpoint: str = "https://api.openai.com/v1/completions",
# ---> 27             apikey: str = config.apikey
#      28     ):
#      29         self.output_model = output_model
#      30         self.reformulation_model = reformulation_model
#
# AttributeError: module 'config' has no attribute 'apikey'

# %% [markdown]
# # This is code unrelated to the rest. Ignore it.

# %%
import requests
import json
import datetime
from typing import List, Tuple

# %%
def get_comments_times(market_link):
    # Returns a list of tuples of the form (comment, datetime)
    slug = market_link.split("/")[-1]
    API_get_slug = f"https://manifold.markets/api/v0/slug/{slug}"
    market_info = requests.get(API_get_slug)
    ID = market_info.json()['id']
    
    API_get_comments = f"https://manifold.markets/api/v0/comments"
    response = requests.get(API_get_comments, params={"contractId": ID})
    comments = response.json()
    comments_info: List[Tuple[str, str]] = []
    for comment in comments:
        # The problem: Comments are structured as a tree. We must find the text from each comment.
        comment_time = datetime.datetime.fromtimestamp(comment["createdTime"]/1000).strftime("%Y-%m-%d %H:%M:%S.%f")
        try:
            comment_info = comment["content"]["content"][0]["content"]
        except KeyError:
            try:
                comments_info.append((comment["text"], comment_time))
                continue
            except KeyError:
                if comment["content"]["content"][0]["type"] == "image":
                    comments_info.append(("[IMAGE]", comment_time))
                    continue
                elif comment["content"]["content"][0]["type"] == "iframe":
                    comments_info.append(("[IFRAME]", comment_time))
                    continue
                print(f'ERROR: {comment}')
                raise KeyError
            
        type_1 = comment_info[0]["type"]
        if type_1 == "text":
            comment_text = comment_info[0]["text"]
        elif type_1 == "mention":
            try:
                comment_text = comment_info[1]["text"]
            except IndexError:
                comment_text = "[MENTION]"
        comments_info.append((comment_text, comment_time))
    return comments_info

# %%
market_link = 'https://manifold.markets/NathanpmYoung/will-biden-be-the-2024-democratic-n'
comment_times = get_comments_times(market_link)

# %%
for comment in comment_times:
    print(comment)
# Out:
# (' See you at the annual wellness rave', '2023-03-05 22:55:45.206000')
# (" That's totally fair, I was just wondering whether there was any sudden news I missed. May the odds be ever in your favor, and may Marianne Williamson become President!", '2023-03-05 03:53:31.037000')
# (' Not interested enough in following prediction markets to make small, safe, long term bets, I would rather have a big bold bet that gets the lizard brain going+ ', '2023-03-05 03:50:05.777000')
# (' What was the reason for that big NO bet?', '2023-03-05 02:42:09.878000')
# (' yeah my dad got it this year and he was fine', '2023-03-03 23:56:49.961000')
# (' I disagree. BCC is almost never lethal, and the lifetime risk of developing it among white people is 1 in 3. By some measures it is the most commonly diagnosed cancer in the US. This sort of thing is as common as dirt among elderly people like Mr. President.', '2023-03-03 21:14:00.732000')
# (' I think this is enough to justify 1 or 2 pts lower, imo ', '2023-03-03 16:31:02.898000')
# ('https://apnews.com/article/biden-skin-cancer-basal-cell-c8868eec1e99b28a9cf497ee39942359', '2023-03-03 16:28:47.381000')
# ('Just initiated a small NO position in the news that Joey had a cancer, but it was removed and everything is fine', '2023-03-03 15:45:45.270000')
# (' PredictIt is back down to 61%!', '2023-02-27 17:01:17.221000')
# ("Come on people! I can't buy cheap shares anymore because you are all starting to come around to reality.", '2023-02-27 16:48:25.062000')
# ('https://www.cbsnews.com/news/ap-interview-biden-ready-to-run-first-lady-jill-biden-says/', '2023-02-25 10:45:05.756000')
# (' There is 100 on NO', '2023-02-24 12:22:54.172000')
# (' Why do I not see even Ṁ10 on “no” from you then?', '2023-02-24 12:21:45.693000')
# (' Also, FDR turned out to be very much replaceable after all. During his last year in office he worked like 1-2 hours a day. Turns out a failed hat salesman from Missouri with a 10th grade education was very much up to the task. ', '2023-02-22 22:09:31.387000')
# (" Unfortunately he couldn't do anything about the hostage crisis or OPEC. That was the year everyone should have been complaining about foreign interference in an election. ", '2023-02-22 18:55:15.755000')
# (' Carter was very good, in particular, for deregulating trucking and commercial air travel', '2023-02-22 18:17:33.343000')
# (' Largely that will depend on what he leaves us with but you are right, he will initially be a hero and rightly so. ', '2023-02-22 13:51:37.328000')
# (' Dying on the job is routinely considered honorable.', '2023-02-22 13:46:28.485000')
# (" Jimmy Carter's legacy was trashed by his own party, specifically Ted Kennedy, who challenged him in the primary. Carter was sabotaged. ", '2023-02-22 13:37:16.290000')
# (" America's SECOND greatest president (Lincoln is untouchable) also was never once photographed in a wheelchair while president and routinely faked the ability to walk using iron braces and leaning on his children. We changed the constitution because of this to limit presidents to two terms. FDR also died much younger than he probably would have had he not been president, but there were no viable alternatives at the time. Biden is not as irreplaceable as FDR, not even close.  ", '2023-02-22 13:31:51.322000')
# (' Classic BTE delusion smh my head', '2023-02-22 13:25:58.700000')
# (" Part of protecting the legacy is winning reelection. See what people did with Jimmy's legacy.", '2023-02-22 13:23:52.343000')
# ('If you assume Biden is thinking about his legacy when making this decision, it is very hard to see how running again could possibly end positively, even if he were to win. Have you seen him walk across the South Lawn recently?? Is he going to be okay with being wheeled out to Marine One when he breaks his hip?? Mentally he appears very sharp, but that is simply not enough. The job is too physically demanding. ', '2023-02-22 12:30:08.537000')
# (" That's because PredictIt and Polymarket are correcting to Manifold", '2023-02-21 02:29:46.169000')
# ('PredictIt', '2023-02-20 14:06:38.461000')
# (' what can i say, we are good at what we do', '2023-02-08 15:21:31.057000')
# (' love it that MM opinion matches "Professional Democratic Lobbyist." spot on from what I\'ve seen.', '2023-02-08 14:49:45.727000')
# ('Great speech, definitely looked like he has some fight in him. I am bowing out of this for now.', '2023-02-08 00:42:32.778000')
# (" Internal cleansing of people who dared challenge Trump's narrative is also relevant, it seems. (Although Democrats seem less likely to perform that.)", '2023-02-07 23:32:40.378000')
# ('Some LLM opinions... ', '2023-02-07 15:45:09.404000')
# (" we certainly need some new, younger,and more progressive dems, but I don't see that happening in 2024. No party will choose to lose the incumbent advantage.", '2023-02-07 11:50:48.957000')
# (' If you say so! It’s all relative. ', '2023-02-07 11:44:12.963000')
# (' He did? Best midterm for a sitting president since 911 ', '2023-02-07 11:18:47.431000')
# (' ‘crushed the midterms’. ', '2023-02-07 07:07:36.982000')
# ("I'm ridin with Biden. Dude crushed the midterms, regardless of the reason for that I think the democrat establishment think he is their best bet for the 2024 election. Let's just hope his physical health don't get worse. ", '2023-02-07 06:01:01.107000')
# ("I'm betting NO.  My personal estimate is only 20% that he runs, but that is likely colored by the fact that I don't want him to run.", '2023-02-06 17:06:00.252000')
# ('I would not have traded between 40 and 60, but >70% seemed too high. ', '2023-02-06 14:20:52.643000')
# (' you pay the fees less if you withdraw less, as I understand it. So it is easier to have enough edge if you bet on markets repeatedly over months and years, and build up your winnings to pay the fees only once at the end. ', '2023-02-01 03:18:28.548000')
# (" You're right. ", '2023-02-01 01:48:08.043000')
# (' He will be opposed.  If only because there is a chance that he drops out along the way.', '2023-02-01 01:37:43.937000')
# (" If you made money, you made money, good for you! It's just hard to beat the crowd the 60% plus amount of time to even break even. If you have the time and inclination you can pick up some money by betting on obviously broken markets. I did this for a year or two but got bored eventually.", '2023-02-01 01:00:11.987000')
# (' Appreciate the details, I did indeed win about 15% of my investment in the Fauci market, which... I guess I should have just left it in my savings account, if what you say is true.', '2023-02-01 00:14:18.159000')
# (' I expect fed tightening to run its course and for them to start loosening rates and employment and the stock market to pick up. I guess “by 2024” is too optimistic. Sometime in 2024 would be more realistic.', '2023-01-31 20:44:47.714000')
# (' You can bet $850 on each market. ', '2023-01-31 20:41:27.856000')
# (' The fees and taxes make it very hard to make money on PredictIt. They charge 10% of winning trades and 5% to withdraw. Then you have to pay taxes on winnings, for me about 40%. I was able to make some money on the 2020 Presidential election but the gain was not worth the risk.', '2023-01-31 20:40:03.726000')
# ("I will buy very large amounts of shares at 10% above or below the Polymarket price. Smaller margins than that aren't worth arbing for me, too much of a hassle etc. If anyone wants to make a bigger trade than the limit orders I have up, ping me and I'll put up bigger ones.", '2023-01-31 19:56:09.646000')
# (" I'd still guess that would lead to a less biased market than if it were Biden vs. Republicans. For an oversimplified example, suppose the true probability of Biden being the nominee is 75%, and the true probability of Harris being the nominee is 25%, and there's nobody else. Then maybe on real-money prediction markets Biden goes to 60% because of bias, and Harris goes to 22% because of less intense bias. Then people notice this only adds up to 82%, so they multiply by 1/0.82 and Biden goes back up to 73%.", '2023-01-31 19:32:43.683000')
# (" The main reason anyone suspects that Biden would lose the nomination or not run is because of his unpopularity. Conservatives surely have an inflated view of Biden's unpopularity, so I would expect them to underestimate his chances of recombination even if they hate all the other Democrats just as much as Biden.", '2023-01-31 18:17:28.941000')
# (" Doesn't conservative bias apply just as strongly against Biden's competitors for the Democratic nomination?", '2023-01-31 17:05:06.533000')
# (' I don’t disagree it’ll get better by November 2024. Simply that ', '2023-01-31 07:47:54.118000')
# (' Recession is already here by technical definitions, no matter what juggling-with-terms Biden tries to avoid this. And this means what ', '2023-01-31 07:20:24.408000')
# (' I don’t know about 2024. All I know is it’s likely to get worse before getting better. 2023 just started. ', '2023-01-31 06:58:15.630000')
# (" Reversion to means suggests that the economy is more likely to be better it is now in 2024. It could get worse, but I wouldn't expect that, unless you have an argument for why it will get worse. ", '2023-01-31 00:08:22.783000')
# (" We're overdue for a recession.", '2023-01-30 21:53:49.482000')
# (" What makes you think it won't?", '2023-01-30 20:55:56.602000')
# (' What makes you think the economy will be ', '2023-01-30 14:47:50.401000')
# ("It's the economy stupid. I think by 2024 the economy will be stronger and his popularity will be up. But I still think he won't run again. The Democratic Party needs some fresh blood.", '2023-01-30 14:30:08.011000')
# ("I'll abstain", '2023-01-30 06:46:23.235000')
# (' Look at those terrible approval ratings. Not a chance he will run. Easy money for you to bid this down to 50%!', '2023-01-24 20:36:41.774000')
# (' Yes! Please buy more No stocks! YES!', '2023-01-24 20:31:51.301000')
# (' He "tanked", meaning that he\'s back to where he was when the Democrats had a great midterm. Hardly proof that he\'s going to not run.', '2023-01-23 19:58:19.774000')
# (" Yeah, you're right. Buy more NO.", '2023-01-23 19:38:09.990000')
# (" Everyone knows he's not well liked. The question is who would run in his place? People hate Kamala too.", '2023-01-23 19:37:57.914000')
# ("C'mon man! Biden just tanked on the 538 favorability polls. Everyone is tired of playing Weekend at Biden's. This is a NO!", '2023-01-23 19:05:50.666000')
# (" What? He wasn't fat...", '2023-01-16 20:51:13.966000')
# (' Tell that to Adlai Stevenson!!', '2023-01-16 20:41:05.755000')
# ('[Deleted by moderator]', '2023-01-16 19:53:10.377000')
# ('[Deleted by moderator]', '2023-01-16 19:52:03.352000')
# (' Americans have a natural trust for fat ass midwesterners', '2023-01-16 11:39:48.075000')
# (" Yeah, I don't really see why people think he would win the nomination. Reminds me of the op-eds last year about Gavin Newsom being the next nominee.", '2023-01-16 02:45:15.040000')
# (' why do you think so highly of JB Pritzker? ', '2023-01-16 02:19:08.569000')
# (' Joe Biden is the Sin-Eater. Failing his ill health or a J.B. Pritzker run, there is no Democrat that could pose a meaningful challenge to his empire. ', '2023-01-16 01:27:44.943000')
# (" nah, it's a nothing burger", '2023-01-15 22:46:50.173000')
# ('Sorry grandpa it’s someone else’s turn to be president', '2023-01-15 01:48:15.942000')
# (' Biden is down to 58% on PredictIt!', '2023-01-13 23:35:48.515000')
# (' Yes, yes! Please believe this and bid the price down to 50% for me! ', '2023-01-13 23:32:51.897000')
# ('Biden is much less likely to run this week than he was last week in my opinion. The classified documents found from his time as VP are not a legal issue like they are for Trump, but they are a big deal politically. ', '2023-01-13 14:27:38.920000')
# (' good point! Please, can someone follow this safe advice and bid this down to 61% so i can get some cheaper Yes shares?', '2023-01-01 22:25:26.519000')
# (" Actually the Polymarket implied probability is 61%, given how it's a total of 109% YES.", '2023-01-01 01:36:38.265000')
# (' 😛', '2022-12-31 19:38:08.386000')
# (' stay mad', '2022-12-30 18:49:25.387000')
# ('No! Wrong direction! 😭 ', '2022-12-30 18:23:42.228000')
# ('@PolyArb this is your jam right here!', '2022-12-30 17:53:14.062000')
# ("I'm still in the search of cheaper Yes shares. If anyone would be kind enough to buy some No shares until this matches Polymarket's 67% then my future play money empire thanks you 🙏 ", '2022-12-30 17:50:06.090000')
# (" That's all true, but I'm still not buying shares because there are other markets that are off by more which resolve sooner.", '2022-12-21 16:01:20.324000')
# (" He could also just become surprisingly unpopular for some reason, or face a surprisingly popular opponent. It just takes a few % to explain the gap. (But it's not surprising for markets here to be off by several %, anyway.)", '2022-12-21 15:29:38.520000')
# (" Sure, but that doesn't seem to get much more than a 5% wedge. (It's looking better now with 69 and 75 than this morning when it was 69 and 79.) The death rate for someone in his age bracket is ", '2022-12-21 15:19:42.170000')
# (' Or becomes physically or mentally unfit to serve.', '2022-12-21 15:14:44.898000')
# (' i mean he could run but, god forbid, not be able to physically make it to the nomination, because he croaks', '2022-12-21 14:08:23.289000')
# ("Isn't this market way out of whack with the question of whether he runs?", '2022-12-21 14:01:21.827000')
# (' At your suggestion, I have now joined PredictIt. They have some fairly ludicrous pricings for the Fauci market and the Senate/Governors market so I believe I will make out more than I put in. I was inspired by Scott Alexander: ', '2022-12-20 00:43:05.564000')
# (" I mean... according to Manifold, PredictIt's not even likely to be running after March, so I don't really see the point of getting into it now...", '2022-12-14 02:39:03.512000')
# (' you all are really bad at this arbitrage thing, it is almost like none of you trust Predictit 😜', '2022-12-14 01:30:48.659000')
# ('Hmph, it only dropped 2 points and my limit orders are at 62%. Come on naysayers buy some more No shares!', '2022-12-13 03:20:46.684000')
# (' I am currently unemployed and do not have the money to do so. I can spare $10 to play with on this site.', '2022-12-12 23:53:27.572000')
# (' How much did you make on PredictIt by correcting this bias?', '2022-12-12 23:20:42.035000')
# (" Well that's good", '2022-12-12 18:10:47.013000')
# (' I think that PredictIt has a conservative bias for questions at the national level that are years away. ', '2022-12-12 18:10:06.382000')
# ('Ironically PredictIt was at 44% back in the middle of November, but this market was at about the current value. PredictIt has gone up by 15% while this market has stayed almost flat.', '2022-12-12 17:25:33.399000')
# ('All you naysays, what have you to say about predictit only having this at 59%?', '2022-12-12 16:03:20.168000')
# (' We have a market for if the chance that he is both running and the DNC is running a primary: ', '2022-12-09 05:51:50.830000')
# (" Nothing obligates the DNC to run a contested primary. He is likely running unopposed if he runs, so its 100 percent once he announces. Things like debates and organizing caucuses take a lot of effort and money that the party isn't going to spend in preparation for the general election. ", '2022-12-08 21:54:43.936000')
# ('Currently implies a 84% chance of winning if he runs.', '2022-12-08 21:52:29.040000')
# ('Related:', '2022-12-08 21:52:05.062000')
# (" Yeah, I'd say my actual estimate for this event is around 70%. But given what I've already put into the market (and my risk tolerance) I'd say the error bars on it are larger than the difference between my expectation and the current market, so I'm not willing to buy more shares . . . yet. ", '2022-12-07 09:41:11.811000')
# (' Exactly. Tetlock found while studying forecasters that those that think in binaries of "will" or "will not" happen do poorly. Those that think in terms of probabilities are much more accurate. It is not actually knowable if Biden will be nominated, just like if I flip a coin, it is not knowable if it will land heads. It\'s all about probabilities. ', '2022-12-07 09:23:33.499000')
# (" It's considerably more complicated than that. I happen to think he will secure the nom, but ignoring the totality of factors is a good way to lose all your mana. ", '2022-12-07 09:20:10.045000')
# (' if yall think the dems will give up the incombant advantage ya dumb as fuck, but please do bid it down so i can get fat gains', '2022-12-07 04:16:54.443000')
# ('🔥 ', '2022-12-06 17:30:59.513000')
# (' ', '2022-12-06 17:19:26.742000')
# ('[hmm]', '2022-12-06 17:05:44.885000')
# ('[IMAGE]', '2022-12-06 17:04:07.087000')
# (' I think the South Carolina move was part of deal with Clyburn for his endorsement. That was arguably the difference maker for Biden, so backward looking, not forward looking signal imo. ', '2022-12-06 10:36:57.472000')
# (" Hah, I saw just a notification for just this comment and panicked that Biden had actually announced that he wouldn't run...", '2022-12-04 19:02:08.489000')
# (' Well this about settles it. Gg boys', '2022-12-04 18:53:51.634000')
# ('GPT estimates a 10% chance that Biden is the 2024 nominee', '2022-12-04 18:48:22.612000')
# (' It\'s not obvious to me that he was talking about running again; he was finishing up a speech about something else when some idiot yelled "Four more years!" and he shut him down. Seems like he was just trying to avoid making it about him, rather than admitting he was reluctant to run.', '2022-12-04 17:34:48.319000')
# ('I am hoping more people believe this off the cuff remark means something and bet the market down so I can pick up some more cheap Yes shares!', '2022-12-04 03:18:57.649000')
# ("Biden let slip his hesitation about running. Publicly, he and his team are suggesting he is running. But this was an unplanned reaction without time to think it through, so seems more honest. Doesn't explain why he and his team don't just say publicly that it's time for someone else to step up to the plate, but regardless, I now put his odds at only 40%", '2022-12-03 21:16:14.867000')
# (" Uh, the real answer is a bit cynical, but basically it's because they get more press coverage for their guys by dragging it out. This also has the advantage of getting some name recognition for their likely voters for people they might not have heard of, like an AG from a city two thousand miles away, etc. ", '2022-12-03 19:00:01.739000')
# (" Why the parties don't make primaries everywhere all at once?", '2022-12-03 18:46:40.700000')
# ("Given that Biden's team has just gotten the DNC to move SC's primary to the front of the docket, I think it seems clear he intends to run for the second term. Moving a state he's strong in to the front of the list to head off prospective challengers does seem like an admission of some weakness, but since the DNC went along with it it seems clear they intend to back him. ", '2022-12-03 12:03:50.013000')
# ('Reported for being a spam account', '2022-12-03 11:19:17.689000')
# ('[IFRAME]', '2022-12-03 11:09:09.084000')
# ('[IMAGE]', '2022-12-03 01:17:32.172000')
# ("As much as I wish it wasn't the case, Biden, the incumbent, will obviously be the nominee, barring any health crisis, which I find unlikely to happen over the next 2 years.", '2022-12-02 14:09:08.803000')
# ("It's not just fees, taxes, and regulations though (PredictIt is terrible but Polymarket doesn't have caps and only has 1% fees, so it's actually not bad). There's a bigger fundamental issue: prediction markets weight people's predictions by how much wealth they invest, which for real-money markets is largely determined by their jobs etc and very little by how good they are at predicting. This is one huge advantage a play-money market like Manifold or a non-market like Metaculus can have over real-money prediction markets: they can do a better job of weighting by past prediction track record. Even though users can buy mana, the amount of mana people have on Manifold is much more correlated to prediction track record than the amount of money they have for a real-money prediction market.", '2022-12-02 08:10:39.646000')
# (' Why would you expect no political bias? ', '2022-12-02 07:42:11.120000')
# (' Nice Substack!', '2022-12-02 07:09:02.416000')
# (" I think that is true in theory if you make a long list of assumptions. But the longer I've spent on prediction markets, the more I believe that they are definitely not efficient markets. Correcting the prices on prediction markets is nowhere near profitable enough for sophisticated funds to be interested, so it's not done in any systematic way. Otherwise we wouldn't see these significant price discrepancies between different platforms, including even between different real-money prediction markets.", '2022-12-01 22:03:10.522000')
# (' Real money markets are strongly expected to have no bias at all. Even if 90% of the traders were hardcore Fox watchers, their money is just a giant incentive for others to make a bunch of money by correcting the odds. If the bias is anywhere, it would be play money markets. Less incentive to keep ideology out of it, and less incentive for more rational people to correct errors. ', '2022-12-01 21:14:07.069000')
# ("I'm sure we will get down to a sane probability of like 40% soon.  :D", '2022-12-01 20:12:24.323000')
# (" It's not bait, it's people agreeing to make trades at mutually agreeable prices. That's how markets are supposed to work!", '2022-12-01 15:03:53.486000')
# (" Set Yes limit orders and then bait No's into buying is such a predictable winning strategy that I wonder how long it will work :)", '2022-12-01 14:52:47.556000')
# (" Yeah that was also my hypothesis for why they were lower. I generally am pretty confident in Metaculus though, so I'm still willing to bet this market down.", '2022-12-01 12:46:25.348000')
# (" The real money markets seem to have a Republican lean compared to Manifold, and Republicans are more likely than Democrats to think that Biden is a person who should retire (he's senile, he's sick, etc.). ", '2022-12-01 12:31:20.097000')
# (' Yep. Lots more forecasts can be found here: ', '2022-12-01 12:12:27.986000')
# (' Real money markets are ~50% as well. Strange how much of an outlier Manifold is, and has been for a while. ', '2022-12-01 12:02:21.657000')
# ('https://www.metaculus.com/questions/11379/2024-democrat-nominee-for-us-prez/?sub-question=5712', '2022-12-01 11:59:50.908000')
# ('With all the limit orders volatility has tightened.', '2022-12-01 11:23:22.375000')
# (' Seems relevant to the current situation', '2022-11-29 01:31:54.937000')
# (' It has happened, though not in awhile. The last was Chester A. Arthur in 1884, who did not mount much of a campaign due to poor health.', '2022-11-27 11:28:40.609000')
# (' That is irrelevant. The precedent that matters is Lyndon Johnson. He was overwhelmed by the burden of the job and decided not to seek reelection. It resulted in Nixon because LBJ did it in a sloppy way. Biden can potentially avoid repeating that mistake.  ', '2022-11-27 11:11:11.079000')
# (' Never a sitting president lost nomination :', '2022-11-27 10:41:31.287000')
# (" The current probaiblities (69% for seeking 2nd term, 60% for winning nomination) imply a 87% chance of Biden winning the nomination if he seeks it, which doesn't seem too unreasonable. I don't think we can infer that either market is clearly mispriced.", '2022-11-26 11:58:19.586000')
# ("The explanation for this market being bet heavily down is simple: it's being bet towards polymarket. However, I don't know why polymarket is so low.", '2022-11-26 11:56:47.131000')
# ('We are slowly getting back up to a more sane probability.', '2022-11-26 11:49:45.527000')
# (" Both predictit and polymarket are historically worse at predicting politics than just simple polling, right? It isn't legal in the US to gamble with real money or I would also bet there. Thinking Buttigeg and Harris have a higher chance of being nominated than Biden is.....at odds with any political expert analysis.", '2022-11-25 01:00:02.893000')
# (' There was some discussion of this market on the discord. Manifold is in fact putting a much higher probability on this than other prediction markets like Polymarket or Predictit. So forget about making free mana, you could be making free U.S. Dollars!', '2022-11-25 00:49:26.592000')
# (' if you can figure out how to bet against other alt-right conspiracy theories, please let me know. Theirs (possibly real) money to be had against them!', '2022-11-25 00:47:32.177000')
# ('I am just analyzing why this market is so far from fundamentals and how it got there.', '2022-11-25 00:43:45.110000')
# (" That's chance of winning if nominated, which is not what this market is about. The correct link is ", '2022-11-24 15:01:13.961000')
# ("Pepe most likely has lots of funds because they predicted well in the past (they have 29k total profit). Therefore, Manifold is (correctly) assigning Pepe's predictions more weight. This is correct from a Bayesian perspective.", '2022-11-24 14:49:07.068000')
# (' Okay, and? This is not a poll.', '2022-11-24 14:11:31.231000')
# (' How do you think I get a dip to happen 😉 ', '2022-11-24 13:01:39.170000')
# ('I don’t understand why people wagering yes are complaining so much. Buy the dips. ', '2022-11-24 12:59:36.924000')
# (" This is exactly what I mean about how ths market is being propped up with fake news. Biden isn't senile.", '2022-11-24 12:46:05.597000')
# (" There are about 330 people who bought Yes on this market and about 150 who bought No. It's not even close which side is preferred.", '2022-11-24 11:49:52.211000')
# ('[MENTION]', '2022-11-24 11:22:08.521000')
# ("I just won big on the Oakland mayor election, but I still have small peanuts compared to Pepe's $50k.", '2022-11-23 20:45:26.133000')
# ('I am confident enough to eventually build this one to my top position. ', '2022-11-23 18:15:48.738000')
# (" If that's true, Pepe is handing out free money, so it can't last too long. I'm not confident enough to want a huge position myself. ", '2022-11-23 17:38:01.516000')
# (" Right now Pepe is propping up No all now their own due to their outsized wealth. The reason I say this isn't that predictive is most of the people in the market think the odds should be higher, but Pepe alone keeps it suppressed.", '2022-11-23 17:25:18.656000')
# (" If you actually watch Biden's public appearances, I think the NOs aren't completely off-base on the health angle - the dude is clearly at least a bit senile. However, I think they're mistaken in believing that the majority of voters are watching Biden's random pressers. Partisans are willing to vote for child molesters and dead people, and hell - just this year we have clear evidence that democrats will vote for brain damage over a republican (at least in PA). ", '2022-11-23 17:19:45.462000')
# (" That only works temporarily, while there are lots of traders with divergent opinions, who haven't been able to fully stock up on all the shares they want, so the price bounces back and forth.  Eventually the market settles and the free money dissipates.", '2022-11-23 14:45:35.659000')
# (' Quite incredibly. The market is remarkably liquid. In my Twitter market, the odds change bit by bit. Here it is everywhere every day.', '2022-11-23 14:42:43.620000')
# (" I don't think this market has any predictive capacity. We are all just playing each other for now. It won't track the real odds of like 95% until we get closer to a payout.", '2022-11-23 13:35:06.444000')
# (" I've noticed that too. I see you have taken the strategy of buying at 50 and selling at 60 to take advantage of that", '2022-11-23 13:32:28.944000')
# ('I think this is the most volatile market in manifold, adjusted for liquidity', '2022-11-23 12:55:53.663000')
# (" it also currently has kamala over biden. I simply do not believe that, feel free to call me delusional. (ole pete b is based though he's my #1)", '2022-11-22 20:55:17.096000')
# (' Election Betting Odds says Newsom is the most electable now, fwiw. ', '2022-11-22 20:26:03.850000')
# (" If you're confident on your prediction You should have put real money on yes in polymarket and make some good money", '2022-11-22 20:21:58.752000')
# (" my money on yes is more of a function of my belief in the other potential candidates. I don't see any of them being strong enough as to overcome bidens incumbents advantage.", '2022-11-22 19:41:46.813000')
# (' people here are just dumb', '2022-11-22 19:11:57.399000')
# ("It's wild how big of a disagreement there is between this market and the real money market. Polymarket says ~50% chance, and it's a high volume market.", '2022-11-22 18:52:41.404000')
# (' Biden is not resigning. That it is at 12% shows the demographics of this market is skewed from reality. 😆', '2022-11-21 20:21:48.825000')
# (" I think its around 40-50%.  I'll bet a lot on no at 66%", '2022-11-21 19:10:57.791000')
# (" I'm sure that many people will still care deeply about it in 2024, but the amount that they care about it will be almost certainly lower than the amount that they cared about it on the day of the Dobbs decision. Looking at polls, it's definitely gone down as an issue since then, and unless some major news stories hit (or something happens like Republicans making it a major campaign issue to outlaw it nation wide), then I would expect it to be less impactful than it was in this election cycle.", '2022-11-21 16:50:55.567000')
# ('The “100.0” and “95%ers” can easily double five to six figure sums on polymarket if they have a point ', '2022-11-21 16:42:48.478000')
# ('A. ', '2022-11-21 16:41:29.307000')
# (" Saying the Dobbs decision will lose momentum is similar to saying the Roe v Wade decision and the pro life movement it stirred up would lose momentum. Losing momentum would mean giving up and I don't see that as a possibility. ", '2022-11-21 16:40:00.692000')
# (' He could be dead and they would still consider running him. The chances of him not running I would tie solely to physical injury, which I would put at much lower than 15% in ~1.8 years.', '2022-11-21 16:27:57.451000')
# (" Here's the link for the challenge:", '2022-11-21 16:27:04.107000')
# (' Ty Gabrielle.', '2022-11-21 16:25:49.578000')
# (" here's a market for you to bet that Ṁ1000: ", '2022-11-21 16:24:36.394000')
# (" Biden can be physicallyimpaired with 15% probability. Also, he can decide not to run. I'd put a 83% that he runs.", '2022-11-21 16:23:57.449000')
# ("This is absolute cope. There's a zero percent chance they do not run Biden again.", '2022-11-21 16:19:44.524000')
# (" But a hairdresser wouldn't suggest a haircut to a bald person. Newsom seems to think that it's worth campaigning for 2024, so he must think there's at least a chance of winning. The chance is probably still low, but I think it would need to be a good deal more than 5% for him to bother.", '2022-11-21 16:17:38.323000')
# (" the problem is that a lot of the success this fall has been related to the Dobbs decision, which probably will have lost even more momentum by 2024 (if the election had been four months ago, the Democrats would probably have kept the house and won another Senate seat or two). It seems more like antipathy for the Republicans than favor towards the Democrats, even though personally I'd say that they've been doing a pretty good job. ", '2022-11-21 16:15:01.533000')
# (' I read the NOs here as having bought into the conspiracy theory that Biden is somehow in poor health. There is no political advantage to switching out a successful incumbent while the party is doing well.', '2022-11-21 16:11:29.166000')
# (' 嗯', '2022-11-21 16:04:35.068000')
# (" There hasn't been a primary challenger to an incumbent president in over 40 years. Right now Dems are doing better than expected by passing their platform through a 50/50 congress, holding control of the Senate, and almost holding the House.", '2022-11-21 16:03:10.744000')
# (" Asking Gavin's opinion on this subject is like asking a hairdresser whether you need a haircut", '2022-11-21 15:54:42.649000')
# (" I'd bet you Ṁ 1000 that if the democratic party makes open primaries, Dark Brandon won't be part of", '2022-11-21 15:53:27.877000')
# (' It would unprecedented to risk an almost guaranteed 2nd Dem term with nothing to gain.', '2022-11-21 15:25:44.149000')
# ("The reason for him to run is he will beat Trump. The reason for him not to run, and the greater concern imo, is that Trump is not going to be the nominee. What Biden should do is open up the Democratic primary and invite people to challenge him. That would require starting that process now, because they need to plan things like the debates that as of now aren't happening. It would be in the country's best interests, and that is actually what I think drives Biden in the end. ", '2022-11-21 14:59:22.347000')
# (" It's not that simple. There is basically no precedent for a sitting president being this old, particularly in the age of social media (high visibility), so the normal pattern of incumbents always winning nomination could be overcome.", '2022-11-21 13:29:56.658000')
# (' Ah! If you look at the order book its just gigagasting and pepe with a lot of limit orders that is keep these odds so low. Wish I had the cash to take all of their money.', '2022-11-21 13:16:43.872000')
# (' He has another term as governor. He is going to run for president in 2028', '2022-11-21 13:11:09.707000')
# (" Gavin Newsom apparently thinks that it's possible for someone else to be the nominee, and he's not exactly the Fox News type. (I agree it should be pretty high odds though.)", '2022-11-21 13:07:51.729000')
# ('This market should be at like 95%, but it looks like there are some fox news watchers in the arena', '2022-11-21 12:36:31.121000')
# ('I just think his health will be too poor to participate in debates. Now...if they take away debates then maaaaybe.', '2022-11-21 10:21:35.986000')
# ('exactly', '2022-11-21 09:30:02.949000')
# ('SODA!', '2022-11-20 23:12:17.757000')
# ('bro literally who tf else', '2022-11-20 02:36:27.015000')
# (' Great point about Dems funding his campaign. I can see that happening for sure. ', '2022-11-19 14:05:03.946000')
# (" Trump is also worse than the replacement ballot, yes. Ironically both Biden and Trump (being united in that characteristic) are best served facing each other. It's a weird time in politics. ", '2022-11-19 13:44:58.880000')
# (" And saying Trump is the presumptive nominee ignores so many factors, such as how is he going to fund his campaign when the major donors have already bailed on him? His dedicated media is going out of business. He had basically zero prominent republicans at his announcement. To say he is the presumptive nominee is like saying the GOP doesn't care about winning, when all evidence is that winning is the only thing they care about. ", '2022-11-19 12:50:09.758000')
# (" Trump couldn't beat someone in a coma right now in a general election. Biden may do well head to head, but as long as they don't nominate Kamala the Dems can't lose to Trump. There has never been a candidate for a major party so completely unable to win new voters than Trump. His popularity among his base doesn't mean shit for the general election. Only people who have never worked in politics think you can benchmark Trump based on historical precedent. Also thinking Biden is going to remain healthy for 6 more years basically ignores his health history, which was not very good the first time he ran for president in 1980. Newsom is obviously the best candidate IMO, it's not even close. ", '2022-11-19 12:46:58.271000')
# ('Given that Trump is the presumptive GOP nominee, I suspect any resistance in the DNC to running Biden again will dissolve. "Pressured to retire due to a combination of age and unpopularity" was by far the most likely route for a NO here, and given that Biden performs pretty well against Trump specifically, if badly against replacement republicans, I see no reason they would decide to toss an incumbency advantage and the guy who\'s already beaten his presumptive opponent once, for an untried candidate. ', '2022-11-19 08:47:14.613000')
# (" Why should he care that he doesn't live until 28? It's a man who loves what he does. It's no burden on him.", '2022-11-18 12:46:04.544000')
# (" So, a Vice-President who is widely considered unelectable by the right, too right-wing by the left, and would be seen to be stabbing Biden in the back if he didn't go willingly, a governor who managed to get a major recall effort going against him in one of the most Democratic states in the nation, and the former mayor of South Bend, Indiana. Not exactly inspiring terror if I'm Biden. ", '2022-11-18 12:28:54.540000')
# (" Democrats need to be pragmatic here, with the Republican party divided by Trump it'd be asking too much to lose the incumbent advantage on a new candidate. Besides, his legislative portfolio speaks for itself.", '2022-11-17 19:34:12.569000')
# (" Lol, retirement is totally reasonable. There is a high probability he won't live until 2028 anyways. As for the alternative, there are many, including Harris, Newsom, and Buttigieg.", '2022-11-17 19:31:01.928000')
# (' Joe really likes his job, he is objectively able to win Trump and what else would he do? Go to Delaware and wait for death?', '2022-11-17 16:33:04.794000')
# ("Real money markets say the odds here are way off. Yes, base rates for presidents in their first term getting nominated again are very high, but Biden's age is a lot worse than most, and in the age of social media, is is also highly visible. 45% sounds right to me. ", '2022-11-17 15:53:53.202000')
# (' Ty. I dislike these conditional markets because of how much mana it consumes, but left a bet there.', '2022-11-16 12:46:58.108000')
# (" Here's the market for whether or not Trump will run as an independent if he loses the Republican nom.", '2022-11-16 12:40:00.254000')
# (" On Trump: if he wants to run, he'll run, even as an independent. And it will make a walk in the park for democrats.", '2022-11-16 12:32:33.097000')
# (" Yeah, it definitely does not happen often, but at 78 at the start of his term, Biden's also the oldest president we've had by far - eight years older than Trump, who was the second oldest ever. The third oldest was Reagan, and he had major health issues in his second term. The fourth oldest was William Henry Harrison, who died shortly into his first term because of an illness. ", '2022-11-16 11:28:05.962000')
# (" This doesn't happen often right? Only LBJ, to my knowledge, has walked away willingly in modern times. ", '2022-11-16 11:17:27.207000')
# (" DeSantis might not be seen as such a walk-in-the-park opponent, so I wouldn't count on that. Plus, even if he's not dead, he might have health issues that make him decide not to be president for another four years. It's a stressful job.", '2022-11-16 10:53:02.888000')
# (' Also Biden just did much better that expected in the midterms. This was the time for him to screw up.', '2022-11-16 10:09:55.339000')
# (" You have ~12% of odds of his health removing him from running. The majority of the risk would be Joe deciding not to run. I can't see how he doesn't run with a walk in the park opponent like Trump", '2022-11-16 09:57:05.672000')
# ("People are crazy on this: average life-expectancy at 80 in a first world country is about 10 years, and sitting presidents almost never lose primaries. A lot of Biden's unpopularity is polarization (as with Trump) rather than dislike from Dems anyway. ", '2022-11-16 07:48:09.225000')
# ('[IMAGE]', '2022-10-09 05:07:33.318000')
# ("“ Donald Trump as the favorite at +250, followed by Florida governor Ron DeSantis at +350. Biden comes in a distant third behind the two Republicans at +550, meaning a $100 bet would net those bullish on Biden's chances to retain the White House $550.”\n\nBiden is ~16% in most betting markets for Prez.  Perhaps plausible he’s only ~30% to win the general election 😉", '2022-07-17 20:32:28.327000')
# ('Well, I worded that wrong above but you get the idea. ', '2022-03-05 09:20:07.948000')
# ("Seems like an awful lot of you guys are betting on health issues? Because far fewer than 37% of first-term US presidents have failed to secure their party's nomination for a reelection bid. ", '2022-03-05 09:17:03.506000')

# %%
def post_comment(market_link, comment, AUTHORIZATION_KEY):
    # Post a comment to a market
    # market_link: The link to the market
    # comment: The comment to post (markdown)
    # AUTHORIZATION_KEY: The authorization key for the Manifold API
    slug = market_link.split("/")[-1]
    API_get_slug = f"https://manifold.markets/api/v0/slug/{slug}"
    market_info = requests.get(API_get_slug)
    ID = market_info.json()['id']
    
    API_POST_URL = "https://manifold.markets/api/v0/comment"
    API_POST_HEADERS = {'Content-Type': 'application/json', 'Authorization': f'Key {AUTHORIZATION_KEY}'}
    API_POST_DATA = {"contractId": ID, "markdown": comment}
    
    response = requests.post(API_POST_URL, headers=API_POST_HEADERS, data=json.dumps(API_POST_DATA))
    return response

# %%
# market_link = "https://manifold.markets/firstuserhere/test-market-4-fe4ad98ccc1f"
# comment = "Yay it worked! (this is still a test) :)"
# AUTHORIZATION_KEY = "YOUR_AUTHORIZATION_KEY"

# post_comment(market_link, comment, AUTHORIZATION_KEY)
# Out:
# <Response [200]>

# %%
for comment_info in comment_times:
    print(comment_info)
# Out:
# (' but that can be faked so', '2023-03-08 23:26:43.168000')
# (' the comment itself might include time', '2023-03-08 23:23:34.167000')
# ('Is there a way to know the precise second someone sent a comment on the API? Writing code to send a comment at the right second at close is easy, but how will you know if someone sent it a second earlier than close?', '2023-03-08 23:16:20.296000')
# (' thats nerd shit that I have no idea about. 😁 ', '2023-03-08 21:46:57.554000')
# ('https://docs.manifold.markets/api#post-v0comment', '2023-03-08 21:42:33.547000')
# (' wdym', '2023-03-08 21:41:31.676000')
# ("/ who's willing to schedule an API call for $1", '2023-03-08 21:35:35.960000')
# (' and it aint me, thats for sure', '2023-03-08 20:35:35.175000')
# ('Seems like the real question is, "who is willing to stay up until 4am for 50 mana?"', '2023-03-08 20:35:16.543000')
# ("Note that you didn't ask about after, but I also won't do that. :)", '2023-03-08 20:31:40.668000')
# (' Nope.', '2023-03-08 20:30:59.666000')
# ('Will you close it before it is set to close?', '2023-03-08 20:27:02.395000')
